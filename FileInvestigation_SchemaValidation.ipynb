# %%
# Created by: Jess Gallo
# Date Created: 09/07/2022
# Last Modified: 09/10/2022
# Description: Data Glacier Week 6 File Investigation and Schema Validation.

# %% [markdown]
# # Task
#
# Take any csv/text file of 2+ GB of your choice. --- (You can do this assignment on Google colab)
#
# Read the file ( Present approach of reading the file )
#
# Try different methods of file reading eg: Dask, Modin, Ray, pandas and present your findings in term of computational efficiency
#
# Perform basic validation on data columns : eg: remove special character , white spaces from the col name
#
# As you already know the schema hence create a YAML file and write the column name in YAML file. --define separator of read and write file, column name in YAML
#
# Validate number of columns and column name of ingested file with YAML.
#
# Write the file in pipe separated text file (|) in gz format.
#
# Create a summary of the file:
#
# Total number of rows,
#
# total number of columns
#
# file size

# %%
# Libraries
import os
import time
import pandas as pd

# %%
# Size of the file
import os
os.path.getsize('C:/Users/Gallo/Downloads/used_cars_data.csv')
# Out:
# 9980208148

# %% [markdown]
# # Pandas

# %%
filename = r'C:/Users/Gallo/Downloads/used_cars_data.csv'

# %%
# %time p_temp = pd.read_csv(filename, encoding = 'ISO-8859-1')
# Out:
# <timed exec>:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
# Wall time: 2min 3s

# %% [markdown]
# # Dask

# %%
import dask.dataframe as dd

# %time d_temp = dd.read_csv(filename, encoding = 'ISO-8859-1')
# Out:
# Wall time: 195 ms

# %% [markdown]
# # Modin & Ray

# %%
os.environ["MODIN_ENGINE"] = "ray"

import ray
ray.shutdown()
ray.init()

import modin.pandas as pd

# %time m_temp = pd.read_csv(filename)
# Out:
# 2022-09-18 18:41:16,241	INFO services.py:1338 -- View the Ray dashboard at http://127.0.0.1:8265

# %% [markdown]
# # Dask has the best computational efficiency

# %%
df = d_temp

# %%
df.info()
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 66 entries, vin to year
# dtypes: object(39), bool(2), float64(19), int64(6)

# %%
len(df.columns)
# Out:
# 66

# %%
# removes special characters
df.columns = df.columns.str.replace('[#,@,&]','')
# Out:
# C:\Users\Gallo\AppData\Local\Temp/ipykernel_10900/418848558.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns=df.columns.str.replace('[#,@,&]','')

# %%
# removes white spaces from columns
df.columns = df.columns.str.replace(' ', '')

# %%
data = df.columns
data
# Out:
# Index(['vin', 'back_legroom', 'bed', 'bed_height', 'bed_length', 'body_type',
#        'cabin', 'city', 'city_fuel_economy', 'combine_fuel_economy',
#        'daysonmarket', 'dealer_zip', 'description', 'engine_cylinders',
#        'engine_displacement', 'engine_type', 'exterior_color', 'fleet',
#        'frame_damaged', 'franchise_dealer', 'franchise_make', 'front_legroom',
#        'fuel_tank_volume', 'fuel_type', 'has_accidents', 'height',
#        'highway_fuel_economy', 'horsepower', 'interior_color', 'isCab',
#        'is_certified', 'is_cpo', 'is_new', 'is_oemcpo', 'latitude', 'length',
#        'listed_date', 'listing_color', 'listing_id', 'longitude',
#        'main_picture_url', 'major_options', 'make_name', 'maximum_seating',
#        'mileage', 'model_name', 'owner_count', 'power', 'price', 'salvage',
#        'savings_amount', 'seller_rating', 'sp_id', 'sp_name', 'theft_title',
#        'torque', 'transmission', 'transmission_display', 'trimId', 'trim_name',
#        'vehicle_damage_category', 'wheel_system', 'wheel_system_display',
#        'wheelbase', 'width', 'year'],
#       dtype='object')

# %% [markdown]
# # Schema Validation

# %%
import logging
import os
import subprocess
import yaml
import pandas as pd
import datetime 
import gc
import re

# %%
# %%writefile utility.py

def read_config_file(filepath):
    with open(filepath, 'r') as stream:
        try:
            return yaml.load(stream, Loader=yaml.Loader)
        except yaml.YAMLError as exc:
            logging.error(exc)

def col_header_val(df,table_config):
    '''
    replace whitespaces in the column
    and standardized column names
    '''
    df.columns = df.columns.str.lower()
    df.columns = df.columns.str.replace('[^\w]','_', regex=True)
    df.columns = list(map(lambda x: x.strip('_'), list(df.columns)))
    df.columns = list(map(lambda x: x.replace(x,'_'), list(df.columns)))
    expected_col = list(map(lambda x: x.lower(),  table_config['columns']))
    expected_col.sort()
    df.columns =list(map(lambda x: x.lower(), list(df.columns)))
    df = df.reindex(sorted(df.columns), axis=1)
    if len(df.columns) == len(expected_col) and list(expected_col)  == list(df.columns):
        print("column name and column length validation passed")
        return 1
    else:
        print("column name and column length validation failed")
        mismatched_columns_file = list(set(df.columns).difference(expected_col))
        print("Following File columns are not in the YAML file",mismatched_columns_file)
        missing_YAML_file = list(set(expected_col).difference(df.columns))
        print("Following YAML columns are not in the file uploaded",missing_YAML_file)
        logging.info(f'df columns: {df.columns}')
        logging.info(f'expected columns: {expected_col}')
        return 0
# Out:
# Overwriting utility.py

# %% [markdown]
# # Write YAML File

# %%
# %%writefile file.yaml
# file_type: csv
# dataset_name: testfile
# file_name: used_cars_data
# table_name: edsurv
# inbound_delimiter: ","
# outbound_delimiter: "|"
# skip_leading_rows: 1
# columns:
#     - vin
#     - back_legroom
#     - bed
#     - bed_height
#     - bed_length
#     - body_type
#     - cabin
#     - city
#     - city_fuel_economy
#     - combine_fuel_economy
#     - daysonmarket
#     - dealer_zip
#     - description
#     - engine_cylinders
#     - engine_displacement
#     - engine_type
#     - exterior_color
#     - fleet
#     - frame_damaged
#     - franchise_dealer
#     - franchise_make
#     - front_legroom
#     - fuel_tank_volume
#     - fuel_type
#     - has_accidents
#     - height
#     - highway_fuel_economy
#     - horsepower
#     - interior_color
#     - isCab
#     - is_certified
#     - is_cpo
#     - is_new
#     - is_oemcpo
#     - latitude
#     - length
#     - listed_date
#     - listing_color
#     - listing_id
#     - longitude
#     - main_picture_url
#     - major_options
#     - make_name
#     - maximum_seating
#     - mileage
#     - model_name
#     - owner_count
#     - power
#     - price
#     - salvag
#     - savings_amount
#     - seller_rating
#     - sp_id
#     - sp_name
#     - theft_title
#     - torque
#     - transmission
#     - transmission_display
#     - trimId
#     - trim_name
#     - vehicle_damage_category
#     - wheel_system
#     - wheel_system_display
#     - wheelbase
#     - width
#     - year
# Out:
# Overwriting file.yaml

# %%
# Read config file
import utility as util

with open('file.yaml') as stream:
    config_data = yaml.safe_load(stream)

# %%
config_data['inbound_delimiter']
# Out:
# ','

# %%
# inspecting data of config file
config_data
# Out:
# {'file_type': 'csv',
#  'dataset_name': 'testfile',
#  'file_name': 'used_cars_data',
#  'table_name': 'edsurv',
#  'inbound_delimiter': ',',
#  'outbound_delimiter': '|',
#  'skip_leading_rows': 1,
#  'columns': ['vin',
#   'back_legroom',
#   'bed',
#   'bed_height',
#   'bed_length',
#   'body_type',
#   'cabin',
#   'city',
#   'city_fuel_economy',
#   'combine_fuel_economy',
#   'daysonmarket',
#   'dealer_zip',
#   'description',
#   'engine_cylinders',
#   'engine_displacement',
#   'engine_type',
#   'exterior_color',
#   'fleet',
#   'frame_damaged',
#   'franchise_dealer',
#   'franchise_make',
#   'front_legroom',
#   'fuel_tank_volume',
#   'fuel_type',
#   'has_accidents',
#   'height',
#   'highway_fuel_economy',
#   'horsepower',
#   'interior_color',
#   'isCab',
#   'is_certified',
#   'is_cpo',
#   'is_new',
#   'is_oemcpo',
#   'latitude',
#   'length',
#   'listed_date',
#   'listing_color',
#   'listing_id',
#   'longitude',
#   'main_picture_url',
#   'major_options',
#   'make_name',
#   'maximum_seating',
#   'mileage',
#   'model_name',
#   'owner_count',
#   'power',
#   'price',
#   'salvag',
#   'savings_amount',
#   'seller_rating',
#   'sp_id',
#   'sp_name',
#   'theft_title',
#   'torque',
#   'transmission',
#   'transmission_display',
#   'trimId',
#   'trim_name',
#   'vehicle_damage_category',
#   'wheel_system',
#   'wheel_system_display',
#   'wheelbase',
#   'width',
#   'year']}

# %%
# reading process of the file using Dask
from dask import dataframe as dd
df_sample = dd.read_csv(filename)

# %%
# reading the file using config file
file_type = config_data['file_type']
source_file = 'C:/Users/Gallo/Downloads/' + config_data['file_name'] + f'.{file_type}'

# %%
import pandas as pd
df = pd.read_csv(source_file, config_data['inbound_delimiter'])
# Out:
# C:\Users\Gallo\anaconda3\envs\GPUenv\lib\site-packages\IPython\core\interactiveshell.py:3441: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\Gallo\AppData\Local\Temp/ipykernel_1404/659631976.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(source_file, config_data['inbound_delimiter'])

# %%
# validate the header of the file
util.col_header_val(df_sample, config_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1404/962463068.py in <module>
#       1 # validate the header of the file
# ----> 2 util.col_header_val(df_sample, config_data)
#
# ~\Jupyter\utility.py in col_header_val(df, table_config)
#      19     expected_col.sort()
#      20     df.columns =list(map(lambda x: x.lower(), list(df.columns)))
# ---> 21     df = df.reindex(sorted(df.columns), axis=1)
#      22     if len(df.columns) == len(expected_col) and list(expected_col)  == list(df.columns):
#      23         print("column name and column length validation passed")
#
# ~\anaconda3\envs\GPUenv\lib\site-packages\dask\dataframe\core.py in __getattr__(self, key)
#    4534             object.__getattribute__(self, key)
#    4535         else:
# -> 4536             raise AttributeError("'DataFrame' object has no attribute %r" % key)
#    4537
#    4538     def __dir__(self):
#
# AttributeError: 'DataFrame' object has no attribute 'reindex'

# %%
print("columns of files are:" , df.columns)
print("columns of YAML are:" , config_data['columns'])
# Out:
# columns of files are: Index(['vin', 'back_legroom', 'bed', 'bed_height', 'bed_length', 'body_type',
#        'cabin', 'city', 'city_fuel_economy', 'combine_fuel_economy',
#        'daysonmarket', 'dealer_zip', 'description', 'engine_cylinders',
#        'engine_displacement', 'engine_type', 'exterior_color', 'fleet',
#        'frame_damaged', 'franchise_dealer', 'franchise_make', 'front_legroom',
#        'fuel_tank_volume', 'fuel_type', 'has_accidents', 'height',
#        'highway_fuel_economy', 'horsepower', 'interior_color', 'isCab',
#        'is_certified', 'is_cpo', 'is_new', 'is_oemcpo', 'latitude', 'length',
#        'listed_date', 'listing_color', 'listing_id', 'longitude',
#        'main_picture_url', 'major_options', 'make_name', 'maximum_seating',
#        'mileage', 'model_name', 'owner_count', 'power', 'price', 'salvage',
#        'savings_amount', 'seller_rating', 'sp_id', 'sp_name', 'theft_title',
#        'torque', 'transmission', 'transmission_display', 'trimId', 'trim_name',
#        'vehicle_damage_category', 'wheel_system', 'wheel_system_display',
#        'wheelbase', 'width', 'year'],
#       dtype='object')
# columns of YAML are: ['vin', 'back_legroom', 'bed', 'bed_height', 'bed_length', 'body_type', 'cabin', 'city', 'city_fuel_economy', 'combine_fuel_economy', 'daysonmarket', 'dealer_zip', 'description', 'engine_cylinders', 'engine_displacement', 'engine_type', 'exterior_color', 'fleet', 'frame_damaged', 'franchise_dealer', 'franchise_make', 'front_legroom', 'fuel_tank_volume', 'fuel_type', 'has_accidents', 'height', 'highway_fuel_economy', 'horsepower', 'interior_color', 'isCab', 'is_certified', 'is_cpo', 'is_new', 'is_oemcpo', 'latitude', 'length', 'listed_date', 'listing_color', 'listing_id', 'longitude', 'main_picture_url', 'major_options', 'make_name', 'maximum_seating', 'mileage', 'model_name', 'owner_count', 'power', 'price', 'salvag', 'savings_amount', 'seller_rating', 'sp_id', 'sp_name', 'theft_title', 'torque', 'transmission', 'transmission_display', 'trimId', 'trim_name', 'vehicle_damage_category', 'wheel_system', 'wheel_system_display', 'wheelbase', 'width', 'year']

# %%
if util.col_header_val(df, config_data)==0:
    print("validation failed")
    # write code to reject the file
else:
    print("col validation passed")
    # write the code to perform further action
    # in the pipleine
# Out:
# column name and column length validation failed
# Following File columns are not in the YAML file ['_']
# Following YAML columns are not in the file uploaded ['bed_height', 'iscab', 'maximum_seating', 'has_accidents', 'city', 'owner_count', 'interior_color', 'model_name', 'latitude', 'longitude', 'price', 'salvag', 'front_legroom', 'vin', 'is_certified', 'is_cpo', 'bed', 'is_new', 'is_oemcpo', 'major_options', 'seller_rating', 'sp_name', 'transmission', 'main_picture_url', 'engine_type', 'exterior_color', 'listed_date', 'description', 'power', 'engine_cylinders', 'torque', 'year', 'franchise_dealer', 'wheelbase', 'cabin', 'listing_color', 'length', 'body_type', 'bed_length', 'make_name', 'height', 'franchise_make', 'fleet', 'horsepower', 'city_fuel_economy', 'wheel_system_display', 'frame_damaged', 'highway_fuel_economy', 'vehicle_damage_category', 'transmission_display', 'combine_fuel_economy', 'daysonmarket', 'fuel_type', 'fuel_tank_volume', 'mileage', 'listing_id', 'engine_displacement', 'sp_id', 'back_legroom', 'savings_amount', 'wheel_system', 'dealer_zip', 'trim_name', 'theft_title', 'width', 'trimid']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1404/3334582872.py in <module>
# ----> 1 if util.col_header_val(df, config_data)==0:
#       2     print("validation failed")
#       3     # write code to reject the file
#       4 else:
#       5     print("col validation passed")
#
# ~\Jupyter\utility.py in col_header_val(df, table_config)
#      29         missing_YAML_file = list(set(expected_col).difference(df.columns))
#      30         print("Following YAML columns are not in the file uploaded",missing_YAML_file)
# ---> 31         logging.info(f'df columns: {df.columns}')
#      32         logging.info(f'expected columns: {expected_col}')
#      33         return 0
#
# NameError: name 'logging' is not defined

# %%
pd.read_csv('C:/Users/Gallo/Downloads/used_cars_data.csv')
# Out:
# C:\Users\Gallo\AppData\Local\Temp/ipykernel_1404/4123766837.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv('C:/Users/Gallo/Downloads/used_cars_data.csv')
#                        vin back_legroom  bed bed_height bed_length  \
# 0        ZACNJABB5KPJ92081      35.1 in  NaN        NaN        NaN
# 1        SALCJ2FX1LH858117      38.1 in  NaN        NaN        NaN
# 2        JF1VA2M67G9829723      35.4 in  NaN        NaN        NaN
# 3        SALRR2RV0L2433391      37.6 in  NaN        NaN        NaN
# 4        SALCJ2FXXLH862327      38.1 in  NaN        NaN        NaN
# ...                    ...          ...  ...        ...        ...
# 3000035  2GNAXJEV0J6261526      39.7 in  NaN        NaN        NaN
# 3000036  1GNERFKW0LJ225508      38.4 in  NaN        NaN        NaN
# 3000037  3FA6P0HD3GR134062      38.3 in  NaN        NaN        NaN
# 3000038  SAJAJ4BNXHA968809        35 in  NaN        NaN        NaN
# 3000039  JN8AT2MT1HW400805      37.9 in  NaN        NaN        NaN
#
#                body_type cabin       city  city_fuel_economy  \
# 0        SUV / Crossover   NaN    Bayamon                NaN
# 1        SUV / Crossover   NaN   San Juan                NaN
# 2                  Sedan   NaN   Guaynabo               17.0
# 3        SUV / Crossover   NaN   San Juan                NaN
# 4        SUV / Crossover   NaN   San Juan                NaN
# ...                  ...   ...        ...                ...
# 3000035  SUV / Crossover   NaN  Fairfield               26.0
# 3000036  SUV / Crossover   NaN    Vallejo               18.0
# 3000037            Sedan   NaN       Napa                NaN
# 3000038            Sedan   NaN  Fairfield               30.0
# 3000039  SUV / Crossover   NaN       Napa               26.0
#
#          combine_fuel_economy  ...  transmission         transmission_display  \
# 0                         NaN  ...             A  9-Speed Automatic Overdrive
# 1                         NaN  ...             A  9-Speed Automatic Overdrive
# 2                         NaN  ...             M               6-Speed Manual
# 3                         NaN  ...             A  8-Speed Automatic Overdrive
# 4                         NaN  ...             A  9-Speed Automatic Overdrive
# ...                       ...  ...           ...                          ...
# 3000035                   NaN  ...             A                    Automatic
# 3000036                   NaN  ...             A                    Automatic
# 3000037                   NaN  ...             A  6-Speed Automatic Overdrive
# 3000038                   NaN  ...             A                    Automatic
# 3000039                   NaN  ...             A                    Automatic
#
#          trimId        trim_name  vehicle_damage_category wheel_system  \
# 0        t83804     Latitude FWD                      NaN          FWD
# 1        t86759            S AWD                      NaN          AWD
# 2        t58994             Base                      NaN          AWD
# 3        t86074       V6 HSE AWD                      NaN          AWD
# 4        t86759            S AWD                      NaN          AWD
# ...         ...              ...                      ...          ...
# 3000035  t72936      1.5T LT FWD                      NaN          FWD
# 3000036  t85763           LS FWD                      NaN          FWD
# 3000037  t57569               SE                      NaN          FWD
# 3000038  t65977  20d Premium AWD                      NaN          AWD
# 3000039  t76529    2017.5 SV FWD                      NaN          FWD
#
#         wheel_system_display wheelbase    width  year
# 0          Front-Wheel Drive  101.2 in  79.6 in  2019
# 1            All-Wheel Drive  107.9 in  85.6 in  2020
# 2            All-Wheel Drive  104.3 in  78.9 in  2016
# 3            All-Wheel Drive    115 in  87.4 in  2020
# 4            All-Wheel Drive  107.9 in  85.6 in  2020
# ...                      ...       ...      ...   ...
# 3000035    Front-Wheel Drive  107.3 in  72.6 in  2018
# 3000036    Front-Wheel Drive  120.9 in  78.6 in  2020
# 3000037    Front-Wheel Drive  112.2 in  83.5 in  2016
# 3000038      All-Wheel Drive  111.6 in  81.7 in  2017
# 3000039    Front-Wheel Drive  106.5 in  72.4 in  2017
#
# [3000040 rows x 66 columns]

# %%
df
# Out:
#                          _        _    _    _    _                _    _  \
# 0        ZACNJABB5KPJ92081  35.1 in  NaN  NaN  NaN  SUV / Crossover  NaN
# 1        SALCJ2FX1LH858117  38.1 in  NaN  NaN  NaN  SUV / Crossover  NaN
# 2        JF1VA2M67G9829723  35.4 in  NaN  NaN  NaN            Sedan  NaN
# 3        SALRR2RV0L2433391  37.6 in  NaN  NaN  NaN  SUV / Crossover  NaN
# 4        SALCJ2FXXLH862327  38.1 in  NaN  NaN  NaN  SUV / Crossover  NaN
# ...                    ...      ...  ...  ...  ...              ...  ...
# 3000035  2GNAXJEV0J6261526  39.7 in  NaN  NaN  NaN  SUV / Crossover  NaN
# 3000036  1GNERFKW0LJ225508  38.4 in  NaN  NaN  NaN  SUV / Crossover  NaN
# 3000037  3FA6P0HD3GR134062  38.3 in  NaN  NaN  NaN            Sedan  NaN
# 3000038  SAJAJ4BNXHA968809    35 in  NaN  NaN  NaN            Sedan  NaN
# 3000039  JN8AT2MT1HW400805  37.9 in  NaN  NaN  NaN  SUV / Crossover  NaN
#
#                  _     _   _  ...  _                            _       _  \
# 0          Bayamon   NaN NaN  ...  A  9-Speed Automatic Overdrive  t83804
# 1         San Juan   NaN NaN  ...  A  9-Speed Automatic Overdrive  t86759
# 2         Guaynabo  17.0 NaN  ...  M               6-Speed Manual  t58994
# 3         San Juan   NaN NaN  ...  A  8-Speed Automatic Overdrive  t86074
# 4         San Juan   NaN NaN  ...  A  9-Speed Automatic Overdrive  t86759
# ...            ...   ...  ..  ... ..                          ...     ...
# 3000035  Fairfield  26.0 NaN  ...  A                    Automatic  t72936
# 3000036    Vallejo  18.0 NaN  ...  A                    Automatic  t85763
# 3000037       Napa   NaN NaN  ...  A  6-Speed Automatic Overdrive  t57569
# 3000038  Fairfield  30.0 NaN  ...  A                    Automatic  t65977
# 3000039       Napa  26.0 NaN  ...  A                    Automatic  t76529
#
#                        _   _    _                  _         _        _     _
# 0           Latitude FWD NaN  FWD  Front-Wheel Drive  101.2 in  79.6 in  2019
# 1                  S AWD NaN  AWD    All-Wheel Drive  107.9 in  85.6 in  2020
# 2                   Base NaN  AWD    All-Wheel Drive  104.3 in  78.9 in  2016
# 3             V6 HSE AWD NaN  AWD    All-Wheel Drive    115 in  87.4 in  2020
# 4                  S AWD NaN  AWD    All-Wheel Drive  107.9 in  85.6 in  2020
# ...                  ...  ..  ...                ...       ...      ...   ...
# 3000035      1.5T LT FWD NaN  FWD  Front-Wheel Drive  107.3 in  72.6 in  2018
# 3000036           LS FWD NaN  FWD  Front-Wheel Drive  120.9 in  78.6 in  2020
# 3000037               SE NaN  FWD  Front-Wheel Drive  112.2 in  83.5 in  2016
# 3000038  20d Premium AWD NaN  AWD    All-Wheel Drive  111.6 in  81.7 in  2017
# 3000039    2017.5 SV FWD NaN  FWD  Front-Wheel Drive  106.5 in  72.4 in  2017
#
# [3000040 rows x 66 columns]

# %% [markdown]
# # Test File

# %%
# Creating test file for this demo:
testdata = {
    'city' : ['Delhi', 'Lima', 'Istanbul','Riyadh'],
    'age' : [34, 30, 16,33],
    'Country' : ['India','Peru','Turkey','Saudi Arabia']
}
import pandas as pd
df = pd.DataFrame(testdata, columns=['city', 'age','Country'])
df.to_csv('used_cars_data.csv',index=False)

# %%
df

# %%
df
